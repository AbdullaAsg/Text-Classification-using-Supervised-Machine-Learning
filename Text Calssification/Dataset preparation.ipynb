# %%
import wikipedia
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('News_dataset.csv',  sep=';')

# %%
df[df['Category']=='tech']
# Out:
#      File_Name                                            Content Category  \
# 1824   001.txt  Ink helps drive democracy in Asia\n\nThe Kyrgy...     tech
# 1825   002.txt  China net cafe culture crackdown\n\nChinese au...     tech
# 1826   003.txt  Microsoft seeking spyware trojan\n\nMicrosoft ...     tech
# 1827   004.txt  Digital guru floats sub-$100 PC\n\nNicholas Ne...     tech
# 1828   005.txt  Technology gets the creative bug\n\nThe hi-tec...     tech
# 1829   006.txt  Wi-fi web reaches farmers in Peru\n\nA network...     tech
# 1830   007.txt  Microsoft releases bumper patches\n\nMicrosoft...     tech
# 1831   008.txt  Virus poses as Christmas e-mail\n\nSecurity fi...     tech
# 1832   009.txt  Apple laptop is 'greatest gadget'\n\nThe Apple...     tech
# 1833   010.txt  Google's toolbar sparks concern\n\nSearch engi...     tech
# 1834   011.txt  UK net users leading TV downloads\n\nBritish T...     tech
# ...

# %%
df.Category.replace('tech','technology',inplace=True)

# %%
df.Category.unique()
# Out:
# array(['business', 'entertainment', 'politics', 'sport', 'technology'],
#       dtype=object)

# %%
df.to_csv('news_dataset_last.csv',sep=";")
